# %% [markdown]
# <table style="float:left; border:none">
#    <tr style="border:none">
#        <td style="border:none">
#            <a href="http://bokeh.pydata.org/">
#            <img
#                src="assets/images/bokeh-transparent.png"
#                style="width:50px"
#            >
#            </a>
#        </td>
#        <td style="border:none">
#            <h1>Bokeh Tutorial</h1>
#        </td>
#    </tr>
# </table>
#
# <div style="float:right;"><h2>10. High Level Charts</h2></div>

# %% [markdown]
# This section covers the `bokeh.charts` interface, which is a high-level API that is especially useful for exploratory data analysis (for instance, in a Jupyter notebook). It provides functions for quickly producing many standard chart types, often with a single line of code. We will look at the following types in this notebook:
#
# * [Scatter Plot](#Scatter-Plot)
# * [Bar Chart](#Bar-Chart)
# * [Histogram](#Histogram)
# * [Box Plot](#Box-Plot)

# %%
from bokeh.io import output_notebook, show

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="01e2808f-1fe1-4719-a0bb-034cc86c0367">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Scatter Plot
#
# A high-level scatter plot is provided by [`bokeh.charts.Scatter`]().
#
# For this section will use the "iris" data set. First let's import it and take a look at a few rows:

# %%
from bokeh.sampledata.iris import flowers

# %%
flowers.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
from bokeh.charts import Scatter

# %% [markdown]
# A basic scatter chart takes the data (in this case a pandas DataFrame) as the first argument, and specifies the `x` and `y` coordinates for the scatter as the names of columns in the data.

# %%
p = Scatter(flowers, x='petal_length', y='petal_width', 
            width=600, height=300)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b430b693-d8e5-451b-b7f1-3fe189f97da5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("b430b693-d8e5-451b-b7f1-3fe189f97da5").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b430b693-d8e5-451b-b7f1-3fe189f97da5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b430b693-d8e5-451b-b7f1-3fe189f97da5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4dad5bd2-c9ac-4ad1-af76-96cacec81855":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"96abd08c-9dc5-46ce-8c0c-0d7c9ac55816","type":"BoxAnnotation"},{"attributes":{"axis_label":"petal_width","formatter":{"id":"3714762f-71d4-415d-a3b4-e4d44b2a35d4","type":"BasicTickFormatter"},"plot":{"id":"15ef01d0-bc65-46a7-905d-51fc6221b3ae","subtype":"Chart","type":"Plot"},"ticker":{"id":"f5ba9ad1-f623-4c19-a7a6-9629f529c232","type":"BasicTicker"}},"id":"6de65e4a-b433-4284-9a57-42317b6d19e7","type":"LinearAxis"},{"attributes":{"plot":{"id":"15ef01d0-bc65-46a7-905d-51fc6221b3ae","subtype":"Chart","type":"Plot"}},"id":"74802bc6-fd64-487c-835b-c72230602d99","type":"PanTool"},{"attributes":{},"id":"b04b2d8b-f430-40cb-97d7-fb3e712ecddf","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"2c07a8f5-cd9c-43be-af3d-7032ad8a51a1","type":"Circle"},{"attributes":{"plot":{"id":"15ef01d0-bc65-46a7-905d-51fc6221b3ae","subtype":"Chart","type":"Plot"}},"id":"178a1402-c157-4637-8da6-1e9410542884","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"96abd08c-9dc5-46ce-8c0c-0d7c9ac55816","type":"BoxAnnotation"},"plot":{"id":"15ef01d0-bc65-46a7-905d-51fc6221b3ae","subtype":"Chart","type":"Plot"}},"id":"d8c5a020-11a0-4e65-b8fe-58cfd208b495","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"15ef01d0-bc65-46a7-905d-51fc6221b3ae","subtype":"Chart","type":"Plot"}},"id":"d4c1a4e7-e46f-4a18-b625-562d2bfab71e","type":"SaveTool"},{"attributes":{"plot":{"id":"15ef01d0-bc65-46a7-905d-51fc6221b3ae","subtype":"Chart","type":"Plot"}},"id":"16c484e3-933d-47ea-ab17-28595661c406","type":"ResetTool"},{"attributes":{"callback":null,"end":2.74,"start":-0.13999999999999999},"id":"1c253ac5-331b-4e76-b2c1-130b60680726","type":"Range1d"},{"attributes":{"plot":{"id":"15ef01d0-bc65-46a7-905d-51fc6221b3ae","subtype":"Chart","type":"Plot"}},"id":"3da27435-dc9a-4e1d-a326-5a330c638216","type":"HelpTool"},{"attributes":{},"id":"f82286f5-c0bc-4184-98d7-829c9ecea6e5","type":"BasicTicker"},{"attributes":{},"id":"3714762f-71d4-415d-a3b4-e4d44b2a35d4","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"23bff327-e648-491a-afb8-8e5ee981f4dd","type":"ColumnDataSource"},"glyph":{"id":"2c07a8f5-cd9c-43be-af3d-7032ad8a51a1","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"9c3cbb07-958c-4aec-a30f-c330a06c2bd5","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"x_values":{"__ndarray__":"...","dtype":"float64","shape":[150]},"y_values":{"__ndarray__":"...","dtype":"float64","shape":[150]}}},"id":"23bff327-e648-491a-afb8-8e5ee981f4dd","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"15ef01d0-bc65-46a7-905d-51fc6221b3ae","subtype":"Chart","t ...

# %% [markdown]
# By passing a column name for the `color` parameter, you can make `Scatter` automatically color the markers according to the groups in that column. Let's also add a legend by specify its location as the value of a `legend` paramter (in this case `"top_left"`)

# %%
p = Scatter(flowers, x='petal_length', y='petal_width', 
            color='species', legend='top_left', width=600, height=300)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="06a979f7-ae31-4a8d-ac96-ee048be5a5cd"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("06a979f7-ae31-4a8d-ac96-ee048be5a5cd").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("06a979f7-ae31-4a8d-ac96-ee048be5a5cd");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '06a979f7-ae31-4a8d-ac96-ee048be5a5cd' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"259f8439-6362-4e26-bd0e-c251982f7224":{"roots":{"references":[{"attributes":{"axis_label":"petal_length","formatter":{"id":"6da15a35-4946-47b6-ac82-3c79e7e1b1ae","type":"BasicTickFormatter"},"plot":{"id":"f5fb924c-f252-4ce0-a8fd-5a791f0f7ce9","subtype":"Chart","type":"Plot"},"ticker":{"id":"c6234677-f3aa-4c74-bd84-9f973027cb3b","type":"BasicTicker"}},"id":"0ffcdc40-0d8a-498b-8b73-a14fb4d06b99","type":"LinearAxis"},{"attributes":{"plot":{"id":"f5fb924c-f252-4ce0-a8fd-5a791f0f7ce9","subtype":"Chart","type":"Plot"}},"id":"cd8110b7-66b3-4a2d-8829-86954e528a36","type":"WheelZoomTool"},{"attributes":{"callback":null,"end":7.49,"start":0.4099999999999999},"id":"ef5e4a6c-3b5b-4552-bfb9-879eef73a3ef","type":"Range1d"},{"attributes":{"overlay":{"id":"203ba8f0-42a7-46b3-bce4-77afa68948be","type":"BoxAnnotation"},"plot":{"id":"f5fb924c-f252-4ce0-a8fd-5a791f0f7ce9","subtype":"Chart","type":"Plot"}},"id":"510f35d3-8a53-43c0-8f60-d03cf6b24676","type":"BoxZoomTool"},{"attributes":{"callback":null,"end":2.74,"start":-0.13999999999999999},"id":"c406410d-fca8-41ab-86c6-0f1b3ba3a2f3","type":"Range1d"},{"attributes":{"items":[{"id":"dbfbb08d-acac-445c-91e8-c0b79a6f12cf","type":"LegendItem"},{"id":"a2ff4241-091b-45d8-a707-fed69a988fb0","type":"LegendItem"},{"id":"de4ce0eb-062d-431e-9d83-127b9a42921b","type":"LegendItem"}],"location":"top_left","plot":{"id":"f5fb924c-f252-4ce0-a8fd-5a791f0f7ce9","subtype":"Chart","type":"Plot"}},"id":"6472d5eb-5499-4c10-8fda-ab0658f447d8","type":"Legend"},{"attributes":{"plot":{"id":"f5fb924c-f252-4ce0-a8fd-5a791f0f7ce9","subtype":"Chart","type":"Plot"}},"id":"b28a2478-dfd7-4912-811e-85a3f85bf80d","type":"SaveTool"},{"attributes":{"label":{"value":"versicolor"},"renderers":[{"id":"7387d3dc-2468-4476-b3dc-bd9b21b59f1a","type":"GlyphRenderer"}]},"id":"a2ff4241-091b-45d8-a707-fed69a988fb0","type":"LegendItem"},{"attributes":{"plot":{"id":"f5fb924c-f252-4ce0-a8fd-5a791f0f7ce9","subtype":"Chart","type":"Plot"}},"id":"505485da-9192-4d4c-a221-6e542006bc11","type":"PanTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"203ba8f0-42a7-46b3-bce4-77afa68948be","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"f5fb924c-f252-4ce0-a8fd-5a791f0f7ce9","subtype":"Chart","type":"Plot"}},"id":"1bb2b5da-9ca2-4d11-b24c-3d707d9e95e2","type":"ResetTool"},{"attributes":{},"id":"a515c8e9-60ba-4140-ad27-46ffabe8587d","type":"ToolEvents"},{"attributes":{"plot":{"id":"f5fb924c-f252-4ce0-a8fd-5a791f0f7ce9","subtype":"Chart","type":"Plot"}},"id":"38481dbe-2d2b-44d9-94b2-eecd05943688","type":"HelpTool"},{"attributes":{"label":{"value":"virginica"},"renderers":[{"id":"ae579107-b8bc-4fe3-b413-59367664d30d","type":"GlyphRenderer"}]},"id":"de4ce0eb-062d-431e-9d83-127b9a42921b","type":"LegendItem"},{"attributes":{},"id":"c6234677-f3aa-4c74-bd84-9f973027cb3b","type":"BasicTicker"},{"attributes":{"data_source":{"id":"e21c4245-0751-42d7-b20a-5e1a5241abb9","type":"ColumnDataSource"},"glyph":{"id":"c4e6e463-fdd6-4e1b-a381-6335c671a7c9","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"ae579107-b8bc-4fe3-b413-59367664d30d","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{ ...

# %% [markdown]
# By passing a column name for the `marker` parameter, you can make `Scatter` automatically vary the marker shapes according to the groups in that column. Let's try that as an exercise.

# %% [markdown]
# ## Exercise 10.1: `bokeh.charts.Scatter`
#
# Vary the marker shape by passing a column name as the `marker` keyword argument

# %%
# Exercise

# %% [markdown]
# # Bar Chart
#
# A high-level bar chart is provided by [`bokeh.charts.Bar`]()
#
# For this section, we will use the "autompg" data set. Let's import it and take a quick look:

# %%
from bokeh.sampledata.autompg import autompg

# %%
autompg.head()
# Out:
#     mpg  cyl  displ   hp  weight  accel  yr  origin                       name
# 0  18.0    8  307.0  130    3504   12.0  70       1  chevrolet chevelle malibu
# 1  15.0    8  350.0  165    3693   11.5  70       1          buick skylark 320
# 2  18.0    8  318.0  150    3436   11.0  70       1         plymouth satellite
# 3  16.0    8  304.0  150    3433   12.0  70       1              amc rebel sst
# 4  17.0    8  302.0  140    3449   10.5  70       1                ford torino

# %%
from bokeh.charts import Bar

# %% [markdown]
# A basic bar chart takes the data (again a DataFrame) as the first value, as well as column names for:
#
# * `label` - a column to group to label the x-axis
# * `values` - a column to aggregate values for each group, to give the bar heights
# * `agg` - the name of an aggregation to perform over the values (e.g., `"mean"`, `"max"`, etc.)
#
# A simple example that also specifies some other properties such as `title` and `legend` is shown below:

# %%
p = Bar(autompg, label='cyl', values='mpg', agg='max', 
        title="Max MPG by CYL", legend=None, tools='crosshair', height=300)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="903d01d1-a71e-4f6c-96f4-79a9b6c6a0db"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("903d01d1-a71e-4f6c-96f4-79a9b6c6a0db").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("903d01d1-a71e-4f6c-96f4-79a9b6c6a0db");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '903d01d1-a71e-4f6c-96f4-79a9b6c6a0db' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"bd1c6ec3-76e8-4946-998b-cd827f7b550a":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"cyl":6}],"color":["#f22c40"],"cyl":[6],"fill_alpha":[0.8],"height":[38.0],"label":[{"cyl":6}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["6"],"y":[19.0]}},"id":"559b9913-a14a-4586-8c88-2aefa0febeb6","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ca4876c4-be33-4f56-ab2b-1b21e2a844d6","type":"Rect"},{"attributes":{"axis_label":"Max( Mpg )","formatter":{"id":"ce077c2b-677c-4ee9-a518-ba0a6b8fa1d0","type":"BasicTickFormatter"},"plot":{"id":"91c9d1bc-9f4f-4c76-96a4-cf620a4c12cc","subtype":"Chart","type":"Plot"},"ticker":{"id":"2957b07a-ca03-45aa-be34-2ead855a3a3c","type":"BasicTicker"}},"id":"1b246f29-164f-40d0-84a5-14e93ec0df79","type":"LinearAxis"},{"attributes":{"callback":null,"end":48.93},"id":"b5e140ff-a3fe-4394-b47f-4167674a4ac6","type":"Range1d"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"557d4e79-44fc-453a-b796-59047d3928f5","type":"Rect"},{"attributes":{"plot":{"id":"91c9d1bc-9f4f-4c76-96a4-cf620a4c12cc","subtype":"Chart","type":"Plot"}},"id":"599a9b42-3182-4440-b5b8-60f82ee96c53","type":"CrosshairTool"},{"attributes":{"data_source":{"id":"783d2d6b-ff8b-4496-9828-bc2487ceb245","type":"ColumnDataSource"},"glyph":{"id":"c3e19fb1-249f-4e4e-abaa-9a7590510cab","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"e0f663e7-2a92-4e51-b0c9-f1416609d5c2","type":"GlyphRenderer"},{"attributes":{},"id":"2957b07a-ca03-45aa-be34-2ead855a3a3c","type":"BasicTicker"},{"attributes":{"below":[{"id":"7cfdb387-16d6-4050-97c7-4783b3bce64e","type":"CategoricalAxis"}],"css_classes":null,"height":300,"left":[{"id":"1b246f29-164f-40d0-84a5-14e93ec0df79","type":"LinearAxis"}],"renderers":[{"id":"8f9724c5-d570-4c4d-b395-ef1e326ffd2a","type":"GlyphRenderer"},{"id":"94a05f19-aad5-4913-9234-e66958c70516","type":"GlyphRenderer"},{"id":"1d40fa71-a78b-4880-a240-d78b27984ba9","type":"GlyphRenderer"},{"id":"e0f663e7-2a92-4e51-b0c9-f1416609d5c2","type":"GlyphRenderer"},{"id":"9f8c5ee0-51f6-4f00-94de-da853eaa7628","type":"GlyphRenderer"},{"id":"7cfdb387-16d6-4050-97c7-4783b3bce64e","type":"CategoricalAxis"},{"id":"1b246f29-164f-40d0-84a5-14e93ec0df79","type":"LinearAxis"},{"id":"53eb93ed-5cf4-483e-a062-4c54ebfd157e","type":"Grid"}],"title":{"id":"a7ec0083-5b0e-4bd6-bcc5-79b3ad9bcf5d","type":"Title"},"tool_events":{"id":"a6634853-856f-46cc-8e65-3b1e7d41e42b","type":"ToolEvents"},"toolbar":{"id":"3992ffc7-476c-4ff1-a04b-7a266ac127a7","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"9a329cfb-3419-4dfe-9567-f01d79bc49fa","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"b5e140ff-a3fe-4394-b47f-4167674a4ac6","type":"Range1d"}},"id":"91c9d1bc-9f4f-4c76-96a4-cf620a4c12cc","subtype":"Chart","type":"Plot"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0ac7fdad-43aa-447d-bf40-253110c0fa76","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"cyl":5}],"color":["#f22c40"],"cyl":[5],"fill_alpha":[0.8],"height":[36.4],"label":[{"cyl":5}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["5"],"y":[18.2]}},"id":"56d3dfda-a96 ...

# %% [markdown]
# By passing another column name as the `group` parameter, the aggregations can be further subdivided by the groups in that column, and the bars grouped visually. The example below demonstrates this, as well as adding a legend by specifying its location:

# %%
p = Bar(autompg, label='yr', values='mpg', agg='median', group='origin', 
        title="Median MPG by YR, grouped by ORIGIN", legend='top_left',
        tools='crosshair', height=300)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c54e4421-b094-4e61-a470-fcead1853728"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("c54e4421-b094-4e61-a470-fcead1853728").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c54e4421-b094-4e61-a470-fcead1853728");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c54e4421-b094-4e61-a470-fcead1853728' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2f5f39bc-00a3-4304-bf6d-9392c35d4346":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"68f3565f-cd16-469c-a1f6-ca77c24e4f6d","type":"Rect"},{"attributes":{"data_source":{"id":"2c84af34-ae8a-4644-a74b-5417386f3105","type":"ColumnDataSource"},"glyph":{"id":"d153e2fc-3cd6-4b2b-ac17-fb581dd89f4f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"cd2db5fc-cbaf-4b9e-8229-24be5c0ed29d","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"97d65262-9d39-40be-9a5b-e91fd618873a","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"03fcd236-c8a5-41b5-8008-269c7168196b","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c61fb05a-aaf3-40db-9085-7bccd202c3bd","type":"Rect"},{"attributes":{},"id":"8c970e50-7599-4267-89b0-a65ac237ef2e","type":"ToolEvents"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"52673c13-a551-4dc3-8e7a-111382b736b8","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d4b2e3fc-4463-478c-b160-5db4f1389b47","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"origin":1,"yr":71}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[18.0],"label":[{"origin":1,"yr":71}],"line_alpha":[1.0],"line_color":["white"],"origin":[1],"width":[0.2],"x":["71:0.25"],"y":[9.0],"yr":[71]}},"id":"3dbb7090-d7e1-4a4f-9556-68f4afb3f43d","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c68aa544-0dc2-491f-ba68-51b997dc0095","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"de482c54-b192-4929-ae2d-e15974fbc390","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d672169b-9383-4ae7-9b22-bba13f12e647","type":"Rect"},{"attributes":{"data_source":{"id":"4c184858-67c0-48ee-9e52-21845baa7ed6","type":"ColumnDataSource"},"glyph":{"id":"03fcd236-c8a5-41b5-8008-269c7168196b","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"e0f25080-4b24-4d65-a557-742ad698a577","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"57cccbab-5465-49d4-967e-69166dd04863","type":"ColumnDataSou ...

# %% [markdown]
# Similarly, bars for subgroups can be stacked visually, by providing a column name for the `stack` parameter. Let's try that as an exercise.

# %% [markdown]
# ## Exercise 10.2: bokeh.charts.Bar
#
# Change the chart above to stack the bars with title "Median MPG by YR, stacked by ORIGIN"

# %%
# Exercise

# %% [markdown]
# # Histogram
#
# A high-level Histogram is provided by [`bokeh.charts.Histogram`]()
#
# For this section, we will construct our own synthetic data set that has values generated from two different probability distributions.

# %%
import pandas as pd
import numpy as np

# %%
# build some distributions
mu, sigma = 0, 0.5
normal = pd.DataFrame({'value': np.random.normal(mu, sigma, 1000), 'type': 'normal'})
lognormal = pd.DataFrame({'value': np.random.lognormal(mu, sigma, 1000), 'type': 'lognormal'})

# %%
# create a pandas data frame
df = pd.concat([normal, lognormal])
df[995:1005]
# Out:
#           type     value
# 995     normal  0.588126
# 996     normal -0.320993
# 997     normal -0.049308
# 998     normal -0.656386
# 999     normal  0.355533
# 0    lognormal  0.903021
# 1    lognormal  2.598891
# 2    lognormal  0.936546
# 3    lognormal  1.893612
# 4    lognormal  1.211671

# %%
from bokeh.charts import Histogram

# %% [markdown]
# A basic histogram takes the data as the first parameter, and a column name as the `values` parameter. Optionally, you can also specify the number of bins to use by giving a value for the `bins` parameter. The example below shows the distribution of ***all*** the values (both the "normal" and "lognormal" values).

# %%
hist = Histogram(df, values='value', bins=30, height=300)
show(hist)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="df82517c-9eb0-4b81-a884-a47556c4db46"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("df82517c-9eb0-4b81-a884-a47556c4db46").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("df82517c-9eb0-4b81-a884-a47556c4db46");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'df82517c-9eb0-4b81-a884-a47556c4db46' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8b46bdf3-6ee9-4438-837d-e4ac6949f264":{"roots":{"references":[{"attributes":{"data_source":{"id":"ffea911e-a0e1-4e41-b370-b8c38a8090a4","type":"ColumnDataSource"},"glyph":{"id":"526ad361-29e0-4a64-b1b2-369ffc30f349","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"ea90ec7f-bf39-4c86-901a-884ef338d97a","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"526ad361-29e0-4a64-b1b2-369ffc30f349","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(2.823453, 3.072787]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[10.0],"label":["(2.823453, 3.072787]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.24933402626159307],"x":["2.9481200000000003"],"y":[5.0]}},"id":"57fc5a22-7899-49cf-be09-ba4235a5d039","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"27db070e-3a0e-4cd2-b51f-2f23b2a11112","type":"ColumnDataSource"},"glyph":{"id":"9ab27b09-2330-4c1f-9023-3dd25e4ff11b","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"f96ff4df-f211-475d-b7e0-6c5d262551ea","type":"GlyphRenderer"},{"attributes":{"location":"top_left","plot":{"id":"63e126f7-5443-4cc0-8681-48d236fde72c","subtype":"Chart","type":"Plot"}},"id":"34c4bfb4-8809-4b25-98ee-1b10590b1c14","type":"Legend"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"cc0b9ebc-1e0a-4e15-b95b-62cdba3d4c67","type":"Rect"},{"attributes":{"plot":{"id":"63e126f7-5443-4cc0-8681-48d236fde72c","subtype":"Chart","type":"Plot"}},"id":"09bfd6da-d071-4789-a408-2f2d0ad6a4ba","type":"PanTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"09bfd6da-d071-4789-a408-2f2d0ad6a4ba","type":"PanTool"},{"id":"ff624ddf-15c9-418a-bb46-c0fdd8ffde60","type":"WheelZoomTool"},{"id":"a9b7adab-8c46-4e2a-8378-a62a6ef46781","type":"BoxZoomTool"},{"id":"56e41500-06a9-4fc9-bd49-8d19f846ebc2","type":"SaveTool"},{"id":"48188282-da8f-43d0-84f8-6cd1b2d92eb8","type":"ResetTool"},{"id":"11aa17b0-7d30-404a-83ca-6b36e3063a9c","type":"HelpTool"}]},"id":"06c4a145-6df3-4a19-81e3-802113bb0225","type":"Toolbar"},{"attributes":{"data_source":{"id":"e91440ec-58bc-4156-bc9c-89b86664ef56","type":"ColumnDataSource"},"glyph":{"id":"cc0b9ebc-1e0a-4e15-b95b-62cdba3d4c67","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"d5a92ece-7e95-4318-a085-dc39117e66ed","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a06371c2-9579-499b-b856-ed38b1fb6322","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0d7603bd-e4e7-4323-ac7c-cb0805b75782","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a6109890-f733-4daa-ba88-83910ff1c7f6","type":"Rect"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1 ...

# %% [markdown]
# It's also possible to generate multiple histograms at once by grouping the data. The column to group by is specified by the `color` parameter (and the histogram for each group is colored differently automatically). Let's try that as an exercise.

# %% [markdown]
# ## Exercise 10.3 `bokeh.charts.bar`
#
# Generate histograms for each "type" of distribution, and add a legend to the top left.

# %%
# Exercise

# %% [markdown]
# # Box Plot
#
# A high-level box plot is provided by [`bokeh.charts.BoxPlot`]()
#
# For this section we will use the "iris" data set again.

# %%
from bokeh.charts import BoxPlot

# %% [markdown]
# A basic box plot takes the data as the first value, as well as column names for:
#
# * `label` - a column to group to label the x-axis
# * `values` - a column to aggregate values for each group
#
# A simple example that also specifies some other properties such as `title` and `legend` is shown below:

# %%
p = BoxPlot(flowers, label='species', values='petal_width', tools='crosshair', color='#aa4444',
            xlabel='', ylabel='petal width, mm', 
            title='Distributions of petal widths', height=300)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a45a91a6-c1c1-49ae-b5e3-37cba7a938f3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("a45a91a6-c1c1-49ae-b5e3-37cba7a938f3").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a45a91a6-c1c1-49ae-b5e3-37cba7a938f3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a45a91a6-c1c1-49ae-b5e3-37cba7a938f3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"167132d6-e200-43de-8582-03449a637970":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c7450848-3ea0-4b52-b1f3-6465ffc71409","type":"Rect"},{"attributes":{"data_source":{"id":"fa4fe1fc-d6fe-421f-8141-a8dfa1a29baf","type":"ColumnDataSource"},"glyph":{"id":"ba0719c1-fc15-4397-a3e8-40bd425537eb","type":"Segment"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"8289f8dc-b016-49d4-8670-7681c3cbd434","type":"GlyphRenderer"},{"attributes":{"items":[{"id":"be533287-8b3a-437e-b340-e3a680ae0587","type":"LegendItem"},{"id":"6a8877c1-3950-403d-9358-ce7408b5d738","type":"LegendItem"},{"id":"7a211d2b-2325-48b3-82c9-3a7c703f5e15","type":"LegendItem"}],"location":"top_left","plot":{"id":"28796de6-b850-4593-9267-81f9e1d753f9","subtype":"Chart","type":"Plot"}},"id":"c57262d5-7ed8-409c-bcc0-68c2cb1cc132","type":"Legend"},{"attributes":{},"id":"4f4ae40e-0749-44b5-8681-b3a8ae39dd43","type":"ToolEvents"},{"attributes":{"callback":null,"column_names":["x0s","y0s","x1s","y1s"],"data":{"chart_index":[{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"}],"species":["versicolor","versicolor","versicolor","versicolor"],"x0s":["versicolor:0.5","versicolor:0.65","versicolor:0.5","versicolor:0.65"],"x1s":["versicolor:0.5","versicolor:0.35","versicolor:0.5","versicolor:0.35"],"y0s":[1.0,1.0,1.5,1.8],"y1s":[1.2,1.0,1.8,1.8]}},"id":"f9f62e46-abbf-41ea-9c86-3b57c508fa52","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"species":"versicolor"}],"color":["#aa4444"],"fill_alpha":[0.8],"height":[0.10000000000000009],"label":[{"species":"versicolor"}],"line_alpha":[1.0],"line_color":["black"],"species":["versicolor"],"width":[0.8],"x":["versicolor"],"y":[1.25]}},"id":"1f6c6c88-2e92-47d8-9522-129cdc7c2f89","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"28796de6-b850-4593-9267-81f9e1d753f9","subtype":"Chart","type":"Plot"}},"id":"c1274a52-8cf3-4e3f-bc55-92ba12cb21ee","type":"CrosshairTool"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"species":"virginica"}],"color":["#aa4444"],"fill_alpha":[0.8],"height":[0.2999999999999998],"label":[{"species":"virginica"}],"line_alpha":[1.0],"line_color":["black"],"species":["virginica"],"width":[0.8],"x":["virginica"],"y":[2.15]}},"id":"1a6c4393-a013-4d2f-b210-f37d37aea208","type":"ColumnDataSource"},{"attributes":{"callback":null,"end":2.63},"id":"820beb30-e92f-42e7-8325-3c7d50b3f899","type":"Range1d"},{"attributes":{"data_source":{"id":"ef517d4f-d02d-46b4-8277-4e017504da08","type":"ColumnDataSource"},"glyph":{"id":"8c28317f-db55-47fe-9211-bb866cb5f29c","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"543b1a08-9121-4a7d-a6ca-5ed0530ebee6","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c1274a52-8cf3-4e3f-bc55-92ba12cb21ee","type":"CrosshairTool"}]},"id":"86e29253-122a-4b76-9a10-6fe53bdf8601","type":"Toolbar"},{"attributes":{"label":{"value":"versicolor"},"renderers":[{"id":"49bffb95-78c4-4c79-880d-9dd5095a9428","type":"GlyphRenderer"},{"id":"d27319c9-f618-45e2-afa9-3fc19124f07f","type":"GlyphRenderer"},{"id":"144bc862-3b33-4315-be71-a3707138350f","type":"GlyphRenderer"}]},"id":"6a8877c1-3950-403d-9358-ce7408b5d738","type":"LegendItem"},{"attributes":{"plot":null,"text":"Distributions of petal widths"},"id":"b975ad98-0259-4ec6-855b-e224aa8c83f7","type":"Title"},{"attributes":{"data_source":{"id":"1f6c6c88-2e92-47d8-9522-129cdc7c2f89","type":"ColumnDataSource"}," ...

# %% [markdown]
# Instead of a single color, the box and whiskers groups can be colored by grouping one of the columns. This is done by passing a column name as the `color` parameter. Let's try that as an exercise.

# %% [markdown]
# ## Exercise 10.4: `bokeh.charts.BoxPlot`
#
# Color the boxes by "species" and add a legend to the top left

# %%
# Exercise

# %% [markdown]
# ---
#
# # Further reading

# %% [markdown]
# http://nbviewer.jupyter.org/github/bokeh/bokeh/tree/0.11.1/examples/charts/file/
#
# http://nbviewer.jupyter.org/github/bokeh/bokeh/tree/0.11.1/examples/howto/charts/
#
# http://nbviewer.jupyter.org/github/bokeh/bokeh-demos/blob/master/presentations/2016-03-pydata-strata/notebooks/Charts.ipynb
#
# http://nbviewer.jupyter.org/github/bokeh/bokeh-demos/blob/master/presentations/2016-03-pydata-strata/notebooks/Charts%20Demo.ipynb
